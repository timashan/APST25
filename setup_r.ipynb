# %%
install.packages("reticulate")
library(reticulate)
# Out:
# Installing package into 'C:/Users/timashan/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'reticulate' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'reticulate'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\timashan\AppData\Local\R\win-library\4.4\00LOCK\reticulate\libs\x64\reticulate.dll to C:\Users\timashan\AppData\Local\R\win-library\4.4\reticulate\libs\x64\reticulate.dll: Permission denied"
# Warning message:
# "restored 'reticulate'"
# The downloaded binary packages are in
# 	C:\Users\timashan\AppData\Local\Temp\Rtmpc9VrRZ\downloaded_packages
# Warning message:
# "package 'reticulate' was built under R version 4.4.2"

# %%
reticulate::py_install("matplotlib")
# Out:
# Using Python: C:/Users/timashan/.pyenv/pyenv-win/versions/3.12.5/python.exe
# Creating virtual environment "~/.virtualenvs/r-reticulate" ...
# + "C:/Users/timashan/.pyenv/pyenv-win/versions/3.12.5/python.exe" -m venv "C:\Users\timashan\Documents/.virtualenvs/r-reticulate"
# Done!
# Installing packages: pip, wheel, setuptools
# + "C:\Users\timashan\Documents/.virtualenvs/r-reticulate/Scripts/python.exe" -m pip install --upgrade pip wheel setuptools
# Virtual environment '~/.virtualenvs/r-reticulate' successfully created.
# Using virtual environment "~/.virtualenvs/r-reticulate" ...
# + "C:\Users\timashan\Documents/.virtualenvs/r-reticulate/Scripts/python.exe" -m pip install --upgrade --no-user matplotlib

# %%
# system("pip install matplotlib")
# Out:
# [1] 0

# %%
library(reticulate)
plt <- import("matplotlib.pyplot")

# %%
file.edit("~/.Rprofile")

# %%
installed.packages()
# Out:
#                Package        LibPath
# backports      backports      C:/Users/timashan/AppData/Local/R/win-library/4.4
# base64enc      base64enc      C:/Users/timashan/AppData/Local/R/win-library/4.4
# brew           brew           C:/Users/timashan/AppData/Local/R/win-library/4.4
# callr          callr          C:/Users/timashan/AppData/Local/R/win-library/4.4
# cli            cli            C:/Users/timashan/AppData/Local/R/win-library/4.4
# collections    collections    C:/Users/timashan/AppData/Local/R/win-library/4.4
# commonmark     commonmark     C:/Users/timashan/AppData/Local/R/win-library/4.4
# cpp11          cpp11          C:/Users/timashan/AppData/Local/R/win-library/4.4
# crayon         crayon         C:/Users/timashan/AppData/Local/R/win-library/4.4
# cyclocomp      cyclocomp      C:/Users/timashan/AppData/Local/R/win-library/4.4
# desc           desc           C:/Users/timashan/AppData/Local/R/win-library/4.4
# digest         digest         C:/Users/timashan/AppData/Local/R/win-library/4.4
# evaluate       evaluate       C:/Users/timashan/AppData/Local/R/win-library/4.4
# fastmap        fastmap        C:/Users/timashan/AppData/Local/R/win-library/4.4
# fs             fs             C:/Users/timashan/AppData/Local/R/win-library/4.4
# glue           glue           C:/Users/timashan/AppData/Local/R/win-library/4.4
# here           here           C:/Users/timashan/AppData/Local/R/win-library/4.4
# highr          highr          C:/Users/timashan/AppData/Local/R/win-library/4.4
# htmltools      htmltools      C:/Users/timashan/AppData/Local/R/win-library/4.4
# IRdisplay      IRdisplay      C:/Users/timashan/AppData/Local/R/win-library/4.4
# IRkernel       IRkernel       C:/Users/timashan/AppData/Local/R/win-library/4.4
# jsonlite       jsonlite       C:/Users/timashan/AppData/Local/R/win-library/4.4
# knitr          knitr          C:/Users/timashan/AppData/Local/R/win-library/4.4
# languageserver languageserver C:/Users/timashan/AppData/Local/R/win-library/4.4
# lazyeval       lazyeval       C:/Users/timashan/AppData/Local/R/win-library/4.4
# lifecycle      lifecycle      C:/Users/timashan/AppData/Local/R/win-library/4.4
# lintr          lintr          C:/Users/timashan/AppData/Local/R/win-library/4.4
# magrittr       magrittr       C:/Users/timashan/AppData/Local/R/win-library/4.4
# pbdZMQ         pbdZMQ         C:/Users/timashan/AppData/Local/R/win-library/4.4
# pillar         pillar         C:/Users/timashan/AppData/Local/R/win-library/4.4
# ⋮              ⋮              ⋮
# base           base           C:/Program Files/R/R-4.4.1/library
# boot           boot           C:/Program Files/R/R-4.4.1/library
# class          class          C:/Program Files/R/R-4.4.1/library
# cluster        cluster        C:/Program Files/R/R-4.4.1/library
# codetools      codetools      C:/Program Files/R/R-4.4.1/library
# compiler       compiler       C:/Program Files/R/R-4.4.1/library
# datasets       datasets       C:/Program Files/R/R-4.4.1/library
# foreign        foreign        C:/Program Files/R/R-4.4.1/library
# graphics       graphics       C:/Program Files/R/R-4.4.1/library
# grDevices      grDevices      C:/Program Files/R/R-4.4.1/library
# grid           grid           C:/Program Files/R/R-4.4.1/library
# KernSmooth     KernSmooth     C:/Program Files/R/R-4.4.1/library
# lattice        lattice        C:/Program Files/R/R-4.4.1/library
# MASS           MASS           C:/Program Files/R/R-4.4.1/library
# Matrix         Matrix         C:/Program Files/R/R-4.4.1/library
# methods        methods        C:/Program Files/R/R-4.4.1/library
# mgcv           mgcv           C:/Program Files/R/R-4.4.1/library
# nlme           nlme           C:/Program Files/R/R-4.4.1/library
# nnet           nnet           C:/Program Files/R/R-4.4.1/library
# parallel       parallel       C:/Program Files/R/R-4.4.1/library
# rpart          rpart          C:/Program Files/R/R-4.4.1/library
# spatial        spatial        C:/Program Files/R/R-4.4.1/library
# splines        splines        C:/Program Files/R/R-4.4.1/library
# stats          stats          C:/Program Files/R/R-4.4.1/library
# stats4         stats4         C:/Program Files/R/R-4.4.1/library
# survival       survival       C:/Program Files/R/R-4.4.1/library
# tcltk          tcltk          C:/Program Files/R/R-4.4.1/library
# tools          tools          C:/Program Files/R/R-4.4.1/library
# translations   translations   C:/Program Files/R/R-4.4.1/library
# utils          utils          C:/Program Files/R/R-4.4.1/library
#                Version  Priority
# backports      1.5.0    NA
# base64enc      0.1-3    NA
# brew           1.0-10   NA
# callr          3.7.6    NA
# cli            3.6.3    NA
# collections    0.3.7    NA
# commonmark     1.9.2    NA
# cpp11          0.5.1    NA
# crayon         1.5.3    NA
# cyclocomp      1.1.1    NA
# desc           1.4.3    NA
# digest         0.6.37   NA
# evaluate       1.0.3    NA
# fastmap        1.2.0    NA
# fs             1.6.5    NA
# glue           1.8.0    NA
# here           1.0.1    NA
# highr          0.11     NA
# htmltools      0.5.8.1  NA
# IRdisplay      1.1      NA
# IRkernel       1.3.2    NA
# jsonlite       1.8.9    NA
# knitr          1.49     NA
# languageserver 0.3.16   NA
# lazyeval       0.2.2    NA
# lifecycle      1.0.4    NA
# lintr          3.1.2    NA
# magrittr       2.0.3    NA
# pbdZMQ         0.3-13   NA
# pillar         1.10.1   NA
# ⋮              ⋮        ⋮
# base           4.4.1    base
# boot           1.3-30   recommended
# class          7.3-22   recommended
# cluster        2.1.6    recommended
# codetools      0.2-20   recommended
# compiler       4.4.1    base
# datasets       4.4.1    base
# foreign        0.8-86   recommended
# graphics       4.4.1    base
# grDevices      4.4.1    base
# grid           4.4.1    base
# KernSmooth     2.23-24  recommended
# lattice        0.22-6   recommended
# MASS           7.3-60.2 recommended
# Matrix         1.7-0    recommended
# methods        4.4.1    base
# mgcv           1.9-1    recommended
# nlme           3.1-164  recommended
# nnet           7.3-19   recommended
# parallel       4.4.1    base
# rpart          4.1.23   recommended
# spatial        7.3-17   recommended
# splines        4.4.1    base
# stats          4.4.1    base
# stats4         4.4.1    base
# survival       3.6-4    recommended
# tcltk          4.4.1    base
# tools          4.4.1    base
# translations   4.4.1    NA
# utils          4.4.1    base
#                Depends
# backports      R (>= 3.0.0)
# base64enc      R (>= 2.9.0)
# brew           NA
# callr          R (>= 3.4)
# cli            R (>= 3.4)
# collections    NA
# commonmark     NA
# cpp11          R (>= 4.0.0)
# crayon         NA
# cyclocomp      NA
# desc           R (>= 3.4)
# digest         R (>= 3.3.0)
# evaluate       R (>= 3.6.0)
# fastmap        NA
# fs             R (>= 3.6)
# glue           R (>= 3.6)
# here           NA
# highr          R (>= 3.3.0)
# htmltools      R (>= 2.14.1)
# IRdisplay      R (>= 3.0.1)
# IRkernel       R (>= 3.2.0)
# jsonlite       methods
# knitr          R (>= 3.6.0)
# languageserver R (>= 3.4.0)
# lazyeval       R (>= 3.1.0)
# lifecycle      R (>= 3.6)
# lintr          R (>= 3.5)
# magrittr       R (>= 3.4.0)
# pbdZMQ         R (>= 3.5.0)
# pillar         NA
# ⋮              ⋮
# base           NA
# boot           R (>= 3.0.0), graphics, stats
# class          R (>= 3.0.0), stats, utils
# cluster        R (>= 3.5.0)
# codetools      R (>= 2.1)
# compiler       NA
# datasets       NA
# foreign        R (>= 4.0.0)
# graphics       NA
# grDevices      NA
# grid           NA
# KernSmooth     R (>= 2.5.0), stats
# lattice        R (>= 4.0.0)
# MASS           R (>= 4.4.0), grDevices, graphics, stats, utils
# Matrix         R (>= 4.4.0), methods
# methods        NA
# mgcv           R (>= 3.6.0), nlme (>= 3.1-64)
# nlme           R (>= 3.5.0)
# nnet           R (>= 3.0.0), stats, utils
# parallel       NA
# rpart          R (>= 2.15.0), graphics, stats, grDevices
# spatial        R (>= 3.0.0), graphics, stats, utils
# splines        NA
# stats          NA
# stats4         NA
# survival       R (>= 3.5.0)
# tcltk          NA
# tools          NA
# translations   NA
# utils          NA
#                Imports
# backports      NA
# base64enc      NA
# brew           NA
# callr          processx (>= 3.6.1), R6, utils
# cli            utils
# collections    NA
# commonmark     NA
# cpp11          NA
# crayon         grDevices, methods, utils
# cyclocomp      callr, crayon, desc, remotes, withr
# desc           cli, R6, utils
# digest         utils
# evaluate       NA
# fastmap        NA
# fs             methods
# glue           methods
# here           rprojroot (>= 2.0.2)
# highr          xfun (>= 0.18)
# htmltools      base64enc, digest, fastmap (>= 1.1.0), grDevices, rlang (>=\n1.0.0), utils
# IRdisplay      methods, repr
# IRkernel       repr (>= 0.4.99), methods, evaluate (>= 0.10), IRdisplay (>=\n0.3.0.9999), pbdZMQ (>= 0.2-1), crayon, jsonlite (>= 0.9.6),\nuuid, digest
# jsonlite       NA
# knitr          evaluate (>= 0.15), highr (>= 0.11), methods, tools, xfun (>=\n0.48), yaml (>= 2.1.19)
# languageserver callr (>= 3.0.0), collections (>= 0.3.0), fs (>= 1.3.1),\njsonlite (>= 1.6), lintr (>= 3.0.0), parallel, R6 (>= 2.4.1),\nroxygen2 (>= 7.0.0), stringi (>= 1.1.7), styler (>= 1.5.1),\ntools, utils, xml2 (>= 1.2.2), xmlparsedata (>= 1.0.3)
# lazyeval       NA
# lifecycle      cli (>= 3.4.0), glue, rlang (>= 1.1.0)
# lintr          backports (>= 1.1.7), codetools, cyclocomp, digest, glue,\nknitr, rex, stats, utils, xml2 (>= 1.0.0), xmlparsedata (>=\n1.0.5)
# magrittr       NA
# pbdZMQ         NA
# pillar         cli (>= 2.3.0), glue, lifecycle, rlang (>= 1.0.2), utf8 (>=\n1.1.0), utils, vctrs (>= 0.5.0)
# ⋮              ⋮
# base           NA
# boot           NA
# class          MASS
# cluster        graphics, grDevices, stats, utils
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        methods, utils, stats
# graphics       grDevices
# grDevices      NA
# grid           grDevices, utils
# KernSmooth     NA
# lattice        grid, grDevices, graphics, stats, utils
# MASS           methods
# Matrix         grDevices, graphics, grid, lattice, stats, utils
# methods        utils, stats
# mgcv           methods, stats, graphics, Matrix, splines, utils
# nlme           graphics, stats, utils, lattice
# nnet           NA
# parallel       tools, compiler
# rpart          NA
# spatial        NA
# splines        graphics, stats
# stats          utils, grDevices, graphics
# stats4         graphics, methods, stats
# survival       graphics, Matrix, methods, splines, stats, utils
# tcltk          utils
# tools          NA
# translations   NA
# utils          NA
#                LinkingTo
# backports      NA
# base64enc      NA
# brew           NA
# callr          NA
# cli            NA
# collections    NA
# commonmark     NA
# cpp11          NA
# crayon         NA
# cyclocomp      NA
# desc           NA
# digest         NA
# evaluate       NA
# fastmap        NA
# fs             NA
# glue           NA
# here           NA
# highr          NA
# htmltools      NA
# IRdisplay      NA
# IRkernel       NA
# jsonlite       NA
# knitr          NA
# languageserver NA
# lazyeval       NA
# lifecycle      NA
# lintr          NA
# magrittr       NA
# pbdZMQ         NA
# pillar         NA
# ⋮              ⋮
# base           NA
# boot           NA
# class          NA
# cluster        NA
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        NA
# graphics       NA
# grDevices      NA
# grid           NA
# KernSmooth     NA
# lattice        NA
# MASS           NA
# Matrix         NA
# methods        NA
# mgcv           NA
# nlme           NA
# nnet           NA
# parallel       NA
# rpart          NA
# spatial        NA
# splines        NA
# stats          NA
# stats4         NA
# survival       NA
# tcltk          NA
# tools          NA
# translations   NA
# utils          NA
#                Suggests
# backports      NA
# base64enc      NA
# brew           testthat (>= 3.0.0)
# callr          asciicast (>= 2.3.1), cli (>= 1.1.0), mockery, ps, rprojroot,\nspelling, testthat (>= 3.2.0), withr (>= 2.3.0)
# cli            callr, covr, crayon, digest, glue (>= 1.6.0), grDevices,\nhtmltools, htmlwidgets, knitr, methods, mockery, processx, ps\n(>= 1.3.4.9000), rlang (>= 1.0.2.9003), rmarkdown, rprojroot,\nrstudioapi, testthat, tibble, whoami, withr
# collections    testthat (>= 2.3.1)
# commonmark     curl, testthat, xml2
# cpp11          bench, brio, callr, cli, covr, decor, desc, ggplot2, glue,\nknitr, lobstr, mockery, progress, rmarkdown, scales, Rcpp,\ntestthat (>= 3.2.0), tibble, utils, vctrs, withr
# crayon         mockery, rstudioapi, testthat, withr
# cyclocomp      testthat
# desc           callr, covr, gh, spelling, testthat, whoami, withr
# digest         tinytest, simplermarkdown
# evaluate       callr, covr, ggplot2 (>= 3.3.6), lattice, methods, pkgload,\nrlang, knitr, testthat (>= 3.0.0), withr
# fastmap        testthat (>= 2.1.1)
# fs             covr, crayon, knitr, pillar (>= 1.0.0), rmarkdown, spelling,\ntestthat (>= 3.0.0), tibble (>= 1.1.0), vctrs (>= 0.3.0), withr
# glue           crayon, DBI (>= 1.2.0), dplyr, knitr, magrittr, rlang,\nrmarkdown, RSQLite, testthat (>= 3.2.0), vctrs (>= 0.3.0),\nwaldo (>= 0.5.3), withr
# here           conflicted, covr, fs, knitr, palmerpenguins, plyr, readr,\nrlang, rmarkdown, testthat, uuid, withr
# highr          knitr, markdown, testit
# htmltools      Cairo, markdown, ragg, shiny, testthat, withr
# IRdisplay      testthat, withr
# IRkernel       testthat, roxygen2
# jsonlite       httr, vctrs, testthat, knitr, rmarkdown, R.rsp, sf
# knitr          bslib, codetools, DBI (>= 0.4-1), digest, formatR, gifski,\ngridSVG, htmlwidgets (>= 0.7), jpeg, JuliaCall (>= 0.11.1),\nmagick, litedown, markdown (>= 1.3), png, ragg, reticulate (>=\n1.4), rgl (>= 0.95.1201), rlang, rmarkdown, sass, showtext,\nstyler (>= 1.2.0), targets (>= 0.6.0), testit, tibble,\ntikzDevice (>= 0.10), tinytex (>= 0.46), webshot, rstudioapi,\nsvglite
# languageserver covr (>= 3.4.0), magrittr (>= 1.5), mockery (>= 0.4.2),\npacman, processx (>= 3.4.1), purrr (>= 0.3.3), testthat (>=\n2.1.0), withr (>= 2.3.0), rmarkdown (>= 2.0)
# lazyeval       knitr, rmarkdown (>= 0.2.65), testthat, covr
# lifecycle      covr, crayon, knitr, lintr, rmarkdown, testthat (>= 3.0.1),\ntibble, tidyverse, tools, vctrs, withr
# lintr          bookdown, crayon, httr (>= 1.2.1), jsonlite, mockery,\npatrick, rlang, rmarkdown, rstudioapi (>= 0.2), testthat (>=\n3.1.5), tibble, tufte, withr (>= 2.5.0)
# magrittr       covr, knitr, rlang, rmarkdown, testthat
# pbdZMQ         NA
# pillar         bit64, DBI, debugme, DiagrammeR, dplyr, formattable, ggplot2,\nknitr, lubridate, nanotime, nycflights13, palmerpenguins,\nrmarkdown, scales, stringi, survival, testthat (>= 3.1.1),\ntibble, units (>= 0.7.2), vdiffr, withr
# ⋮              ⋮
# base           methods
# boot           MASS, survival
# class          NA
# cluster        MASS, Matrix
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        NA
# graphics       NA
# grDevices      KernSmooth
# grid           NA
# KernSmooth     MASS, carData
# lattice        KernSmooth, MASS, latticeExtra, colorspace
# MASS           lattice, nlme, nnet, survival
# Matrix         MASS, datasets, sfsmisc, tools
# methods        codetools
# mgcv           parallel, survival, MASS
# nlme           Hmisc, MASS, SASmixed
# ...
# splines        Matrix, methods
# stats          MASS, Matrix, SuppDists, methods, stats4
# stats4         NA
# survival       NA
# tcltk          NA
# tools          codetools, methods, xml2, curl, commonmark, knitr, xfun,\nmathjaxr, V8
# translations   NA
# utils          methods, xml2, commonmark, knitr, jsonlite
#                Enhances
# backports      NA
# base64enc      png
# brew           NA
# callr          NA
# cli            NA
# collections    NA
# commonmark     NA
# cpp11          NA
# crayon         NA
# cyclocomp      NA
# desc           NA
# digest         NA
# evaluate       NA
# fastmap        NA
# fs             NA
# glue           NA
# here           NA
# highr          NA
# htmltools      knitr
# IRdisplay      NA
# IRkernel       NA
# jsonlite       NA
# knitr          NA
# languageserver NA
# lazyeval       NA
# lifecycle      NA
# lintr          data.table
# magrittr       NA
# pbdZMQ         NA
# pillar         NA
# ⋮              ⋮
# base           chron, date, round
# boot           NA
# class          NA
# cluster        mvoutlier, fpc, ellipse, sfsmisc
# codetools      NA
# compiler       NA
# datasets       NA
# foreign        NA
# graphics       vcd
# grDevices      NA
# grid           NA
# KernSmooth     NA
# lattice        chron, zoo
# MASS           NA
# Matrix         SparseM, graph
# methods        NA
# mgcv           NA
# nlme           NA
# nnet           NA
# parallel       snow, Rmpi
# rpart          NA
# spatial        NA
# splines        NA
# stats          Kendall, coin, multcomp, pcaPP, pspearman, robustbase
# stats4         NA
# survival       NA
# tcltk          NA
# tools          NA
# translations   NA
# utils          NA
#                License                     License_is_FOSS
# backports      GPL-2 | GPL-3               NA
# base64enc      GPL-2 | GPL-3               NA
# brew           GPL (>= 2)                  NA
# callr          MIT + file LICENSE          NA
# cli            MIT + file LICENSE          NA
# collections    MIT + file LICENSE          NA
# commonmark     BSD_2_clause + file LICENSE NA
# cpp11          MIT + file LICENSE          NA
# crayon         MIT + file LICENSE          NA
# cyclocomp      MIT + file LICENSE          NA
# desc           MIT + file LICENSE          NA
# digest         GPL (>= 2)                  NA
# evaluate       MIT + file LICENSE          NA
# fastmap        MIT + file LICENSE          NA
# fs             MIT + file LICENSE          NA
# glue           MIT + file LICENSE          NA
# here           MIT + file LICENSE          NA
# highr          GPL                         NA
# htmltools      GPL (>= 2)                  NA
# IRdisplay      MIT + file LICENSE          NA
# IRkernel       MIT + file LICENSE          NA
# jsonlite       MIT + file LICENSE          NA
# knitr          GPL                         NA
# languageserver MIT + file LICENSE          NA
# lazyeval       GPL-3                       NA
# lifecycle      MIT + file LICENSE          NA
# lintr          MIT + file LICENSE          NA
# magrittr       MIT + file LICENSE          NA
# pbdZMQ         GPL-3                       NA
# pillar         MIT + file LICENSE          NA
# ⋮              ⋮                           ⋮
# base           Part of R 4.4.1             NA
# boot           Unlimited                   NA
# class          GPL-2 | GPL-3               NA
# cluster        GPL (>= 2)                  NA
# codetools      GPL                         NA
# compiler       Part of R 4.4.1             NA
# datasets       Part of R 4.4.1             NA
# foreign        GPL (>= 2)                  NA
# graphics       Part of R 4.4.1             NA
# grDevices      Part of R 4.4.1             NA
# grid           Part of R 4.4.1             NA
# KernSmooth     Unlimited                   NA
# lattice        GPL (>= 2)                  NA
# MASS           GPL-2 | GPL-3               NA
# Matrix         GPL (>= 2) | file LICENCE   NA
# methods        Part of R 4.4.1             NA
# mgcv           GPL (>= 2)                  NA
# nlme           GPL (>= 2)                  NA
# nnet           GPL-2 | GPL-3               NA
# parallel       Part of R 4.4.1             NA
# rpart          GPL-2 | GPL-3               NA
# spatial        GPL-2 | GPL-3               NA
# splines        Part of R 4.4.1             NA
# stats          Part of R 4.4.1             NA
# stats4         Part of R 4.4.1             NA
# survival       LGPL (>= 2)                 NA
# tcltk          Part of R 4.4.1             NA
# tools          Part of R 4.4.1             NA
# translations   Part of R 4.4.1             NA
# utils          Part of R 4.4.1             NA
#                License_restricts_use OS_type MD5sum NeedsCompilation Built
# backports      NA                    NA      NA     yes              4.4.0
# base64enc      NA                    NA      NA     yes              4.4.0
# brew           NA                    NA      NA     no               4.4.2
# callr          NA                    NA      NA     no               4.4.2
# cli            NA                    NA      NA     yes              4.4.2
# collections    NA                    NA      NA     yes              4.4.2
# commonmark     NA                    NA      NA     yes              4.4.2
# cpp11          NA                    NA      NA     no               4.4.2
# crayon         NA                    NA      NA     no               4.4.2
# cyclocomp      NA                    NA      NA     no               4.4.2
# desc           NA                    NA      NA     no               4.4.2
# digest         NA                    NA      NA     yes              4.4.2
# evaluate       NA                    NA      NA     no               4.4.2
# fastmap        NA                    NA      NA     yes              4.4.2
# fs             NA                    NA      NA     yes              4.4.2
# glue           NA                    NA      NA     yes              4.4.2
# here           NA                    NA      NA     no               4.4.2
# highr          NA                    NA      NA     no               4.4.2
# htmltools      NA                    NA      NA     yes              4.4.2
# IRdisplay      NA                    NA      NA     no               4.4.2
# IRkernel       NA                    NA      NA     no               4.4.2
# jsonlite       NA                    NA      NA     yes              4.4.2
# knitr          NA                    NA      NA     no               4.4.2
# languageserver NA                    NA      NA     yes              4.4.2
# lazyeval       NA                    NA      NA     yes              4.4.2
# lifecycle      NA                    NA      NA     no               4.4.2
# lintr          NA                    NA      NA     no               4.4.2
# magrittr       NA                    NA      NA     yes              4.4.2
# pbdZMQ         NA                    NA      NA     yes              4.4.1
# pillar         NA                    NA      NA     no               4.4.2
# ⋮              ⋮                     ⋮       ⋮      ⋮                ⋮
# base           NA                    NA      NA     NA               4.4.1
# boot           NA                    NA      NA     no               4.4.1
# class          NA                    NA      NA     yes              4.4.1
# cluster        NA                    NA      NA     yes              4.4.1
# codetools      NA                    NA      NA     no               4.4.1
# compiler       NA                    NA      NA     NA               4.4.1
# datasets       NA                    NA      NA     NA               4.4.1
# foreign        NA                    NA      NA     yes              4.4.1
# graphics       NA                    NA      NA     yes              4.4.1
# grDevices      NA                    NA      NA     yes              4.4.1
# grid           NA                    NA      NA     yes              4.4.1
# KernSmooth     NA                    NA      NA     yes              4.4.1
# lattice        NA                    NA      NA     yes              4.4.1
# MASS           NA                    NA      NA     yes              4.4.1
# Matrix         NA                    NA      NA     yes              4.4.1
# methods        NA                    NA      NA     yes              4.4.1
# mgcv           NA                    NA      NA     yes              4.4.1
# nlme           NA                    NA      NA     yes              4.4.1
# nnet           NA                    NA      NA     yes              4.4.1
# parallel       NA                    NA      NA     yes              4.4.1
# rpart          NA                    NA      NA     yes              4.4.1
# spatial        NA                    NA      NA     yes              4.4.1
# splines        NA                    NA      NA     yes              4.4.1
# stats          NA                    NA      NA     yes              4.4.1
# stats4         NA                    NA      NA     NA               4.4.1
# survival       NA                    NA      NA     yes              4.4.1
# tcltk          NA                    NA      NA     yes              4.4.1
# tools          NA                    NA      NA     yes              4.4.1
# translations   NA                    NA      NA     NA               4.4.1
# utils          NA                    NA      NA     yes              4.4.1
