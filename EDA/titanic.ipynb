# %%
df <- read.csv("titanic-train.csv")
head(df)
attach(df)
# Out:
#   PassengerId Survived Pclass
# 1 1           0        3
# 2 2           1        1
# 3 3           1        3
# 4 4           1        1
# 5 5           0        3
# 6 6           0        3
#   Name                                                Sex    Age SibSp Parch
# 1 Braund, Mr. Owen Harris                             male   22  1     0
# 2 Cumings, Mrs. John Bradley (Florence Briggs Thayer) female 38  1     0
# 3 Heikkinen, Miss. Laina                              female 26  0     0
# 4 Futrelle, Mrs. Jacques Heath (Lily May Peel)        female 35  1     0
# 5 Allen, Mr. William Henry                            male   35  0     0
# 6 Moran, Mr. James                                    male   NA  0     0
#   Ticket           Fare    Cabin Embarked
# 1 A/5 21171         7.2500       S
# 2 PC 17599         71.2833 C85   C
# 3 STON/O2. 3101282  7.9250       S
# 4 113803           53.1000 C123  S
# 5 373450            8.0500       S
# 6 330877            8.4583       Q

# %%
c <- rainbow(2,  start = 0.0399, end = 0.59)

# %%
par(bg="white")
t <- table(Survived, Sex)
print(t)
barplot(t)
# Out:
#         Sex
# Survived female male
#        0     81  468
#        1    233  109
# plot without title

# %%
par(bg="white")
t <- table(Survived, Pclass)
print(t)
barplot(t)
# Out:
#         Pclass
# Survived   1   2   3
#        0  80  97 372
#        1 136  87 119
# plot without title

# %%
par(bg="white")
t <- table(Survived, Age)
hist(t)

not_survived_ages <- df$Age[df$Survived == 0]

breaks <- seq(0, max(df$Age, na.rm = TRUE), by = 5)

par(mfrow = c(2, 1)) # Set layout for two histograms

hist(survived_ages, breaks = breaks, col = "lightblue", main = "Age Distribution of Survivors",
     xlab = "Age", ylab = "Frequency", border = "blue")

hist(not_survived_ages, breaks = breaks, col = "pink", main = "Age Distribution of Non-Survivors",
     xlab = "Age", ylab = "Frequency", border = "red")

par(mfrow = c(1, 1)) # Reset layout
# Out:
# Plot with title "Histogram of t"
# Plot with title "Age Distribution of Non-Survivors"
