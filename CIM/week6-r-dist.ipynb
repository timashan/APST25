# %%
set.seed(100)
rnorm(5, 15, 3)
# Out:
# [1] 13.49342 15.39459 14.76325 17.66035 15.35091

# %%
par(bg="white", mfrow=c(2,1))
hist(rnorm(10000, 5, 3))
hist(runif(10000, 1, 3))
# Out:
# Plot with title "Histogram of runif(10000, 1, 3)"
